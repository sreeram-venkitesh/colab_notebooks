# %% [markdown]
# <a href="https://colab.research.google.com/github/fillerInk/colab_notebooks/blob/master/Vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Notebook #n - Feb 18 2019

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.quiver(0,0,3,4, scale_units='xy', angles='xy', scale=1)
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %%
plt.quiver(0,0,3,4, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,-3,4, scale_units='xy', angles='xy', scale=1, color='y')
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %%
def plot_vectors(vecs):
  colors=['r','y','g','b']
  i =0
  for vec in vecs:
    plt.quiver(vec[0],vec[1],vec[2],vec[3], scale_units='xy', angles='xy', scale=1, color=colors[i%len(colors)] )
    i=i+1
  plt.xlim(-10,10)
  plt.ylim(-10,10)
  plt.show()

# %%
plot_vectors([(0,0,3,4)])

# %%
plot_vectors([np.asarray((1,1,1,1)),np.asarray((0,0,-3,-3))])

# %%
vecs = [np.asarray((1,1,1,1)),np.asarray((0,0,-3,-3))]

# %%
vecs[0] + vecs[1]
# Out:
# array([ 1,  1, -2, -2])

# %%
fibonacci_vectors=[ np.asarray((0,0,1,1))]
for i in range (5):
  fibonacci_vectors.append(fibonacci_vectors[i]+np.asarray((0,0,1,6)))
plot_vectors(fibonacci_vectors)

# %%
import numpy as np

a = [2,2,2]
b = [3,4,5]

np.dot(a,b)
# Out:
# 24
